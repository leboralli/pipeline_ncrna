# %% [markdown]
# # Script para filtrar lncRNAs de mRNAs e estimar a quantidade de cada

# %%
import json
import glob
import sys
import os
import re
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
file_totalLnRNAs = pd.read_table('/home/boralli/workdir/pipeline_v4/FEELNC/CLASSIFIER/lncRNA_classes.txt')
#     file_totalLnRNAs = rea 
file_totalLnRNAs
# Out:
#         isBest  lncRNA_gene  lncRNA_transcript     partnerRNA_gene  \
# 0            1  MSTRG.39394      MSTRG.39394.1   ENSG00000271151.1
# 1            0  MSTRG.39394      MSTRG.39394.1  ENSG00000172845.15
# 2            0  MSTRG.39394      MSTRG.39394.1  ENSG00000172845.15
# 3            0  MSTRG.39394      MSTRG.39394.1  ENSG00000172845.15
# 4            0  MSTRG.39394      MSTRG.39394.1  ENSG00000172845.15
# ...        ...          ...                ...                 ...
# 322074       0  MSTRG.56786      MSTRG.56786.1  ENSG00000083097.14
# 322075       0  MSTRG.56786      MSTRG.56786.1  ENSG00000013375.16
# 322076       1  MSTRG.46816      MSTRG.46816.1  ENSG00000185565.12
# 322077       1  MSTRG.40455  ENST00000412747.1   ENSG00000233751.1
# 322078       0  MSTRG.40455  ENST00000412747.1  ENSG00000124003.13
#
#        partnerRNA_transcript      direction        type  distance  \
# 0          ENST00000605739.1  strand_unknow  intergenic       982
# ...
